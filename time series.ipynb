# %%
# !pip install pandas_datareader

# %%
import pandas_datareader as pdr

# %%
import pandas as pd

# %%
from datetime import datetime

# %%
import yfinance as yf

# %%
data = yf.download("PRICOLLTD.NS",start="2024-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
# Price         Adj Close        Close         High          Low         Open  \
# Ticker     PRICOLLTD.NS PRICOLLTD.NS PRICOLLTD.NS PRICOLLTD.NS PRICOLLTD.NS
# Date
# 2024-01-01   380.700012   380.700012   382.200012   378.399994   379.850006
# 2024-01-02   378.700012   378.700012   383.399994   372.000000   381.100006
# 2024-01-03   374.649994   374.649994   380.149994   373.000000   379.700012
# 2024-01-04   369.850006   369.850006   377.850006   366.149994   374.649994
# 2024-01-05   371.399994   371.399994   377.000000   367.200012   368.700012
# ...                 ...          ...          ...          ...          ...
# 2024-11-28   480.500000   480.500000   483.000000   470.549988   475.000000
# 2024-11-29   483.750000   483.750000   485.399994   471.000000   471.000000
# 2024-12-02   495.049988   495.049988   495.899994   483.750000   485.000000
# 2024-12-03   499.049988   499.049988   523.799988   495.549988   519.000000
# ...

# %%
#Simple Moving Average

# %%
data['Open'].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
data["Open:10 days rolling"]=data["Open"].rolling(window=10,min_periods=1).mean()
data["Open:30 days rolling"]=data["Open"].rolling(window=30,min_periods=1).mean()
data["Open:50 days rolling"]=data["Open"].rolling(window=50,min_periods=1).mean()

# %%
data
# Out:
# Price         Adj Close        Close         High          Low         Open  \
# Ticker     PRICOLLTD.NS PRICOLLTD.NS PRICOLLTD.NS PRICOLLTD.NS PRICOLLTD.NS
# Date
# 2024-01-01   380.700012   380.700012   382.200012   378.399994   379.850006
# 2024-01-02   378.700012   378.700012   383.399994   372.000000   381.100006
# 2024-01-03   374.649994   374.649994   380.149994   373.000000   379.700012
# 2024-01-04   369.850006   369.850006   377.850006   366.149994   374.649994
# 2024-01-05   371.399994   371.399994   377.000000   367.200012   368.700012
# ...                 ...          ...          ...          ...          ...
# 2024-11-28   480.500000   480.500000   483.000000   470.549988   475.000000
# 2024-11-29   483.750000   483.750000   485.399994   471.000000   471.000000
# 2024-12-02   495.049988   495.049988   495.899994   483.750000   485.000000
# 2024-12-03   499.049988   499.049988   523.799988   495.549988   519.000000
# ...

# %%
data[["Open","Open:10 days rolling"]].plot(xlim=['2024-01-01','2024-12-31'],figsize=(15,7))
# Out:
# <Axes: xlabel='Date'>

# %%
data[["Open","Open:10 days rolling","Open:30 days rolling","Open:50 days rolling"]].plot(xlim=['2024-01-01','2024-12-31'],figsize=(15,7))
# Out:
# <Axes: xlabel='Date'>

# %%
#Expanding

data['Open'].expanding().mean().plot(figsize=(10,3))
# Out:
# <Axes: xlabel='Date'>

# %%
data['Open'].expanding().mean()
# Out:
# Ticker      PRICOLLTD.NS
# Date
# 2024-01-01    379.850006
# 2024-01-02    380.475006
# 2024-01-03    380.216675
# 2024-01-04    378.825005
# 2024-01-05    376.800006
# ...                  ...
# 2024-11-28    446.295537
# 2024-11-29    446.405334
# 2024-12-02    446.576107
# 2024-12-03    446.895155
# 2024-12-04    447.136404
#
# [228 rows x 1 columns]

# %%
data['Open'].expanding(10).mean().plot(figsize=(10,3))
# Out:
# <Axes: xlabel='Date'>

# %%
data['Open'].expanding(10).mean().plot(figsize=(10,3))
# Out:
# <Axes: xlabel='Date'>

# %%
#Exponential Moving Average

# %%
data['EMA_0.1']=data['Open'].ewm(alpha=0.1,adjust=False).mean()

# %%
data
# Out:
# Price         Adj Close        Close         High          Low         Open  \
# Ticker     PRICOLLTD.NS PRICOLLTD.NS PRICOLLTD.NS PRICOLLTD.NS PRICOLLTD.NS
# Date
# 2024-01-01   380.700012   380.700012   382.200012   378.399994   379.850006
# 2024-01-02   378.700012   378.700012   383.399994   372.000000   381.100006
# 2024-01-03   374.649994   374.649994   380.149994   373.000000   379.700012
# 2024-01-04   369.850006   369.850006   377.850006   366.149994   374.649994
# 2024-01-05   371.399994   371.399994   377.000000   367.200012   368.700012
# ...                 ...          ...          ...          ...          ...
# 2024-11-28   480.500000   480.500000   483.000000   470.549988   475.000000
# 2024-11-29   483.750000   483.750000   485.399994   471.000000   471.000000
# 2024-12-02   495.049988   495.049988   495.899994   483.750000   485.000000
# 2024-12-03   499.049988   499.049988   523.799988   495.549988   519.000000
# ...

# %%
data[["Open","EMA_0.1"]].plot(xlim=['2024-01-01','2024-12-31'],figsize=(15,7))
# Out:
# <Axes: xlabel='Date'>

# %%
data['EMA_0.3']=data['Open'].ewm(alpha=0.3,adjust=False).mean()

# %%
data[["Open","EMA_0.3"]].plot(xlim=['2024-01-01','2024-12-31'],figsize=(15,7))
# Out:
# <Axes: xlabel='Date'>

# %%
data['EMA_0.5']=data['Open'].ewm(alpha=0.5,adjust=False).mean()

# %%
data
# Out:
# Price         Adj Close        Close         High          Low         Open  \
# Ticker     PRICOLLTD.NS PRICOLLTD.NS PRICOLLTD.NS PRICOLLTD.NS PRICOLLTD.NS
# Date
# 2024-01-01   380.700012   380.700012   382.200012   378.399994   379.850006
# 2024-01-02   378.700012   378.700012   383.399994   372.000000   381.100006
# 2024-01-03   374.649994   374.649994   380.149994   373.000000   379.700012
# 2024-01-04   369.850006   369.850006   377.850006   366.149994   374.649994
# 2024-01-05   371.399994   371.399994   377.000000   367.200012   368.700012
# ...                 ...          ...          ...          ...          ...
# 2024-11-28   480.500000   480.500000   483.000000   470.549988   475.000000
# 2024-11-29   483.750000   483.750000   485.399994   471.000000   471.000000
# 2024-12-02   495.049988   495.049988   495.899994   483.750000   485.000000
# 2024-12-03   499.049988   499.049988   523.799988   495.549988   519.000000
# ...

# %%
data['EMA_5Days']=data['Open'].ewm(span=5).mean()

# %%
data[['Open','EMA_0.3','EMA_5Days']].plot(xlim=['2024-01-01','2024-12-31'],figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>
